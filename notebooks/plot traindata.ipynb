# %% [markdown]
# ## 2D KPE Model

# %%
import matplotlib.pyplot as plt

# %%
# Plot train acc
file_name = "../results/simple_2d_model_20220321-195443_train_acc.txt"
accs = []
with open(file_name) as file:
    accs = file.readlines()
    accs = [float(item.rstrip()) for item in accs]
epochs = [i+1 for i in range(len(accs))]
plt.figure(figsize=(7,6))
plt.plot(epochs, accs)
plt.title("Training 2D KPE Train Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
# plot train loss
file_name = "../results/simple_2d_model_20220321-195443_train_loss.txt"
losses= []
with open(file_name) as file:
    losses = file.readlines()
    losses = [float(item.rstrip()) for item in losses]
epochs = [i+1 for i in range(len(accs))]
plt.figure(figsize=(7,6))
plt.plot(epochs, losses)
plt.title("Training 2D KPE Train Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
# plot val acc
file_name = "../results/simple_2d_model_20220321-195443_val_acc.txt"
accs = []
with open(file_name) as file:
    accs = file.readlines()
    accs = [float(item.rstrip()) for item in accs]
epochs = [i+1 for i in range(len(accs))]
plt.figure(figsize=(7,6))
plt.plot(epochs, accs)
plt.title("Training 2D KPE Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
# plot val loss
file_name = "../results/simple_2d_model_20220321-195443_val_loss.txt"
losses= []
with open(file_name) as file:
    losses = file.readlines()
    losses = [float(item.rstrip()) for item in losses]
epochs = [i+1 for i in range(len(losses))]
plt.figure(figsize=(7,6))
plt.plot(epochs, losses)
plt.yscale('log')
plt.title("Training 2D KPE Validation Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %% [markdown]
# ## Lifting Training Data

# %%
# Plot train acc
file_name = "../results/lifting_depth_model_20220323-150326_train_acc.txt"
accs = []
with open(file_name) as file:
    accs = file.readlines()
    accs = [float(item.rstrip()) for item in accs]
epochs = [i+1 for i in range(len(accs))]
plt.figure(figsize=(7,6))
plt.plot(epochs, accs)
plt.title("Training 3D Lifting Train Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
# plot train loss
file_name = "../results/lifting_depth_model_20220323-150326_train_loss.txt"
losses= []
with open(file_name) as file:
    losses = file.readlines()
    losses = [float(item.rstrip()) for item in losses]
epochs = [i+1 for i in range(len(losses))]
plt.figure(figsize=(7,6))
plt.plot(epochs, losses)
plt.title("Training 3D Lifting Train Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()

# %%
# plot val acc
file_name = "../results/lifting_depth_model_20220323-150326_val_acc.txt"
accs = []
with open(file_name) as file:
    accs = file.readlines()
    accs = [float(item.rstrip()) for item in accs]
epochs = [i+1 for i in range(len(accs))]
plt.figure(figsize=(7,6))
plt.plot(epochs, accs)
plt.title("Training 3D Lifting Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.show()

# %%
# plot val loss
file_name = "../results/lifting_depth_model_20220323-150326_val_loss.txt"
print(len(losses))
losses= []
with open(file_name) as file:
    losses = file.readlines()
    losses = [float(item.rstrip()) for item in losses]
epochs = [i+1 for i in range(len(losses))]
plt.figure(figsize=(7,6))
plt.plot(epochs, losses)
plt.yscale('log')
plt.title("Training 3D Lifting Validation Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show()
# Out:
# 150
